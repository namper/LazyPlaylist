# %%
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# read and manipulate data
df = pd.read_csv('data/data_v1.csv')
df['vector'] = df['vector'].map(lambda x: np.fromstring(x, sep=';'))
df
# Out:
#            name  id           vector
# 0    pink_floyd   1  [1.0, 0.9, 0.0]
# 1  led_zeppelin   2  [0.9, 1.0, 0.1]
# 2    kate_perry   3  [0.0, 0.0, 1.0]

# %%
def heatmap2d(arr: np.ndarray):
    plt.imshow(arr, cmap='viridis')
    plt.colorbar()
    plt.show()
    
z = np.array([i for i in df['vector']])
heatmap2d(z)

# %%
z.T[0]
# Out:
# array([1. , 0.9, 0. ])

# %%
rgb = ['r', 'g', 'b']
def plot3d(arr: np.ndarray):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    for point in arr:
        ax.scatter(*point, c=rgb[random.randint(0, 2)])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')
    plt.show()
plot3d(z)
